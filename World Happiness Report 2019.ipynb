# %% [markdown]
# Hey there!!
# This is my first Exploratory Data Analysis .To analyza a dataset I have taken a data of World Happiness Report 2019 .This dataset I have downloaded from Kaggle.

# %% [markdown]
# # World Happiness Report 2019

# %% [markdown]
# It is a report which is published by Sustainable Developemnt Solutions Network.This report ranks 149 Countries by how happy their citizens perceive themselves to be.Basically ,respondants are asked to rate their own current lives on a scale of 0-10 during survey .Ranking is done on the basis of Six broad Parameters -GDP Per Capita,Social Support,Healthy life expectancy,Freedom to make life choices ,Generosity and Perceptions of Corruption .
# Meanings of the term involved in it:
# 1. GDP Per Capita-It shows a country's GDP divided by its total Population.
# 2. Social Support-It means having family ,friends etc. to share their feelings .
# 3. Health-Healthy Life expectancy stands for average number of years that a person speds healthy.
# 4. Freedom-It is person's autonomy to perform action according to his own desire .
# 5. Generosity-It stands for how much a people is contributing to charity.
# 6. Corruption-It is the abuse of entrusted power .

# %% [markdown]
# # Questions in my mind

# %% [markdown]
# Before I started visualizing the data I had some questions in my mind .Here I want to share some questions -
# 1. What is that one factor which makes country Happy?
# 2. Does interaction  play any role in making people happy?
# 3. Is Happiness determined by income of a nation?
# 4. Does healthy way of living has any impact on Happiness of People?
# 5. Is it freedom to take life decisisons which increases happiness?
# 6. Does generosity have any impact on happiness score?
# 7. Does Corruption impacts happiness?

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# Then I understand the parameters of data and checked missing values ,erros,meaingless data etc.

# %% [markdown]
# # Visualizing the data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import the data
data = pd.read_csv(r"C:\Users\lenovo\Desktop\2019.csv")

# %%
data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#To see Upper value
data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#To see lower values
data.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
#To find the shape
data.shape
# Out:
# (156, 9)

# %%
#To collect information about data 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
#To find the statistics of Data
data.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
#To get the columns
data.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#To find GDP per capita value
data['GDP per capita']
# Out:
# 0      1.340
# 1      1.383
# 2      1.488
# 3      1.380
# 4      1.396
#        ...
# 151    0.359
# 152    0.476
# 153    0.350
# 154    0.026
# 155    0.306
# Name: GDP per capita, Length: 156, dtype: float64

# %%
#Univariate Analysis
#Histogram of Score data to find Maximum and minimum value
plt.hist(data['Score'])
plt.title=('Maximum and minimum Happiness Score')
plt.xlabel=('Happiness Score')
plt.show()

# %% [markdown]
# To extract interesting insights from the data I have visualized data using different plots .First of all I conducted a univariate analysis in order to describe the data and find possible patterns.
#           Using Matplotlib I created a histogram for all the continuous variables .Using Histogram I have found maximum and minimum values .For that I  have plotted the graph of Happiness Score.Using that I have found the maximum and minimum values of Happiness Score .

# %%
#Univariate Analysis
#Barplot between Overall Rank and Healthy life expectancy 
x = data['Overall rank'].head(5)
y = data['Healthy life expectancy'].tail(5)
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Plot between Overall rank and Healthy life expectancy')
plt.xlabel('Overall rank',fontsize = 15)
plt.ylabel('Healthy life expectancy',fontsize = 15)


 
# Horizontal Bar Plot
plt.bar(x,y)
 
# Show Plot
plt.show()

# %%
#Univariate analysis 
#Using Subplot
top_5 = data['Country or region'].head(5)
bottom_5 = data['Country or region'].tail(5)

# %%
x1 = data['Country or region'].head(5)
y1 = data['GDP per capita'].head(5)

x2 = data['Country or region'].tail(5)
y2 = data['GDP per capita'].tail(5)

fig = plt.figure(figsize =(10, 7))
plot1 = plt.figure(1)
plt.xlabel("Name of Countries")
plt.ylabel("GDP Per Capita")
plt.title("Top five countries with their GDP Per capita")
plt.bar(x1,y1)

fig = plt.figure(figsize =(10, 7))
plot2 = plt.figure(2)
plt.xlabel("Name of Countries")
plt.ylabel("GDP Per capita")
plt.title("Bottom five countries with their GDP Per capita")
plt.bar(x2,y2)

plt.show()

# %%
#Bivariate Analysis
#Scatterplot between Score and Corruption
plt.scatter(data['Perceptions of corruption'],data['Score'])
plt.xlabel("Happiness score")
plt.ylabel("Corruption")
plt.title("Happiness Vs Corruption")
plt.show()

# %%
#Scatterplot between Freedom to make choices and Score
plt.scatter(data['Freedom to make life choices'],data['Score'])
plt.xlabel("Happiness score")
plt.ylabel("Freedom to make life choices")
plt.title("Happiness Vs Freedom to make  life choices")
plt.show()

# %%
#Scatterplot between Overall Score and Generosity 
plt.scatter(data['Generosity'],data['Score'])
plt.xlabel("Happiness score")
plt.ylabel("Generosity")
plt.title("Happiness Vs Generosity")
plt.show()

# %%
#Scatterplot between Overall Score  and Healthy life expectancy
plt.scatter(data['Healthy life expectancy'],data['Score'])
plt.xlabel("Happiness score")
plt.ylabel("Healthy life expectancy")
plt.title("Happiness Vs Healthy life expectancy")
plt.show()

# %%
#Scatterplot between Overall score and Social support 
plt.scatter(data['Social support'],data['Score'])
plt.xlabel("Happiness score")
plt.ylabel("Social support")
plt.title("Happiness Vs Social support")
plt.show()

# %%
#Happiness Vs GDP per capita
#Using Scatterplot
plt.scatter(data['GDP per capita'],data['Score'])
plt.xlabel("Happiness score")
plt.ylabel("GDP Per Capita")
plt.title("Happiness Vs GDP Per capita")
plt.show()

# %% [markdown]
# Then I did Bivariate Analysis using Scatterplot .I have plotted Scatterplot for different variables .
# 1. GDP per capita is high for those countries which have Highest Happiness Score
# 2. Social support was high for those contries which have highest happiness Score
# 3. Health Life expectancy also has positive relation with Happiness Score and vice versa
# 4. Those countries which has highest happiness score has freedom to make life choices

# %%
plt.figure(figsize=(10,10))
sns.distplot(data.Score)
# Out:
# C:\Users\lenovo\Downloads\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Score', ylabel='Density'>

# %%
#Using Pair plot
plt.figure(figsize=(10,10))
sns.pairplot(data)
plt.show()

# %%
#To find the correlation between data 
#Using Heatmap
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# I have also used Seaborn library to find Correlation Matrix between variables.From this Heatmap it is clear that GDP Per capita is also strongly correlated  with life expectancy .

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion ,Correlation analysis shows that the main variables associated with Happiness Score are GDP Per capita ,Social Support & Life Expectancy .Ultimately ,we can say that money plays a crucial role in Happiness Detemination .

# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# Q-What is the one factor which makes country Happy?
# A-GDP Per Capita
#
# Q-Does interaction  with others  play any role in making people happy?
# A-Yes,Using Scatter plot we have found that Social support was high for those countries which has highest happiness score .
#
# Q-Is Happiness determined by Income of a nation ?
# A-Yes
#
# Q-Does Healthy way of living has any impact on Happiness of People?
# A-Yes,It has a positive relation
#
# Q-Is it freedom to take life decisions increases happiness?
# A-Yes
#
# Q-Does generosity have any impact on happiness score?
# A-Not much
#
# Q-Does Corruption impacts Happiness?
# A-Not much
